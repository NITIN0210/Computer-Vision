# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import fftconvolve,convolve2d
import math
from PIL import Image
import numpy as np 
import copy
from collections import deque

# %%
#Multiple Face Detection using Haar-Cascade

face_detector_model = cv2.CascadeClassifier('facefrontal.xml')

# reading the input image now
cap = cv2.VideoCapture(0)
while cap.isOpened():
    _, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_detector_model.detectMultiScale(gray,1.1, 4 )
    for (x,y, w, h) in faces:
        cv2.putText(frame, "Person1", (x-10, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
        cv2.rectangle(frame, pt1 = (x,y),pt2 = (x+w, y+h), color = (255,255,0),thickness =  3)
        roi_gray = gray[y:y+h,x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        cv2.imshow("window", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# %%
#Detect faces
patch= cv2.imread(r"E:\u\sem1\cv\aat3\question5\faces\image1.jpg", 0)
plt.figure(figsize = (20,2))
plt.imshow(patch,cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# - These are the values thhat are calcullated manually based on the 20 different images taken

# %% [markdown]
# Accuracy
# - Accuracy=(TP+FP)/(TP+TN+FP+FN)
# - Accuracy=17/20=0.85

# %% [markdown]
# Precision
# - Presion=TP/(TP+FP)
# - Precision=11/18=0.6111

# %% [markdown]
# Recall
# - Recall=TP/(TP+FN)
# - Recall=11/11=1

# %% [markdown]
# Intersection over Union
# - IOU=(area of overlap)/(area of union)
# - IOU=59/71=0.83098591549
# - this is for one image(59 is area of overlap and 71 is area of union)
# - These are approximate values
