# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import fftconvolve,convolve2d
import math
from PIL import Image
import numpy as np 
import copy
from collections import deque

# %%
# Image 1 is original image with marker
# Image 2 is translated with marker
img= cv2.imread(r"E:\u\sem1\cv\aat3\question6\images\image1.jpg", 0)
img2= cv2.imread(r"E:\u\sem1\cv\aat3\question6\images\image3.jpg", 0)
plt.figure(figsize = (20,2))
plt.imshow(img,cmap='gray', vmin=0, vmax=255)
plt.show()
plt.figure(figsize = (20,2))
plt.imshow(img2,cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
D=457
T=25
b=546.1
f=1203.54736624058 
z=(b*f)/(D-T) 
print('The Disparity based depth estimation is '+str(z)+'mm')
# Out:
# The Disparity based depth estimation is 1521.428742370326mm
